# %%
import pandas as pd
import numpy as np
timestamp = ['2020-02-16 16:38:56', '2020-11-21 11:59:50',
'2020-08-13 12:54:24', '2020-10-12 06:14:03', '2020-06-13 02:54:24', '2020-08-13 12:54:24',
'2020-11-21 11:59:50', '2020-08-13 12:54:24',
'2020-12-19 00:44:47', '2019-01-01 04:30:07']
data = {'timestamp': timestamp,
        'transient_1' : [ 11, 62, 3, 62, 11, 3, 62, 62, 62, 11],
        'transient_2': [166,166, 0,225,225, 0,225, 0,225,300],
        'transient_3' : [867, 83,903, 8, 29,105,424,455,410,437],
        'transient_4': [ 94,756,927,191,611,117, 45,268,180,273],
        'transient_5': [ 95,272,754, 5,477,749, 1,390,943, 4],
        'transient_6': [105,424,455,410,437, 45,268,180,550,273],
        'transient_7': [112,201,355,342,495,135,689, 2,958, 661],
        'transient_8' : [163,735,848, 67,855,198,302,112,416, 217],
        'transient_9' : [ 1,390,495,943, 4,408,163,661,484,943],}
df = pd.DataFrame(data=data)

# %%
df.head()
# Out:
#              timestamp  transient_1  transient_2  transient_3  transient_4  \
# 0  2020-02-16 16:38:56           11          166          867           94
# 1  2020-11-21 11:59:50           62          166           83          756
# 2  2020-08-13 12:54:24            3            0          903          927
# 3  2020-10-12 06:14:03           62          225            8          191
# 4  2020-06-13 02:54:24           11          225           29          611
#
#    transient_5  transient_6  transient_7  transient_8  transient_9
# 0           95          105          112          163            1
# 1          272          424          201          735          390
# 2          754          455          355          848          495
# 3            5          410          342           67          943
# 4          477          437          495          855            4

# %%
features = df.drop(['timestamp'], axis=1)

# %%
df['average']= df.mean(axis='columns')
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_10832/1169198003.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['average']= df.mean(axis='columns')

# %%
df
# Out:
#              timestamp  transient_1  transient_2  transient_3  transient_4  \
# 0  2020-02-16 16:38:56           11          166          867           94
# 1  2020-11-21 11:59:50           62          166           83          756
# 2  2020-08-13 12:54:24            3            0          903          927
# 3  2020-10-12 06:14:03           62          225            8          191
# 4  2020-06-13 02:54:24           11          225           29          611
# 5  2020-08-13 12:54:24            3            0          105          117
# 6  2020-11-21 11:59:50           62          225          424           45
# 7  2020-08-13 12:54:24           62            0          455          268
# 8  2020-12-19 00:44:47           62          225          410          180
# 9  2019-01-01 04:30:07           11          300          437          273
#
#    transient_5  transient_6  transient_7  transient_8  transient_9     average
# ...

# %%
df['average_7_max'] = df['average'].nlargest(7)

# %%
df
# Out:
#              timestamp  transient_1  transient_2  transient_3  transient_4  \
# 0  2020-02-16 16:38:56           11          166          867           94
# 1  2020-11-21 11:59:50           62          166           83          756
# 2  2020-08-13 12:54:24            3            0          903          927
# 3  2020-10-12 06:14:03           62          225            8          191
# 4  2020-06-13 02:54:24           11          225           29          611
# 5  2020-08-13 12:54:24            3            0          105          117
# 6  2020-11-21 11:59:50           62          225          424           45
# 7  2020-08-13 12:54:24           62            0          455          268
# 8  2020-12-19 00:44:47           62          225          410          180
# 9  2019-01-01 04:30:07           11          300          437          273
#
#    transient_5  transient_6  transient_7  transient_8  transient_9  \
# 0           95          105          112          163            1
# ...

# %%
df['transient_1'].mean()
# Out:
# 34.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      10 non-null     object
#  1   transient_1    10 non-null     int64
#  2   transient_2    10 non-null     int64
#  3   transient_3    10 non-null     int64
#  4   transient_4    10 non-null     int64
#  5   transient_5    10 non-null     int64
#  6   transient_6    10 non-null     int64
#  7   transient_7    10 non-null     int64
#  8   transient_8    10 non-null     int64
#  9   transient_9    10 non-null     int64
#  10  average        10 non-null     float64
#  11  average_7_max  7 non-null      float64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 1.1+ KB

# %%
#df.nlargest(7, ['transient_1'].mean())

# %%
for i in features:
    average_7_max = []
    dt = features.nlargest(7, [i])
    dt.append(average_7_max)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
average_7_max
# Out:
# []

# %%
df['timestamp'].dt.month_name()
# Out:
# 0    February
# 1    November
# 2      August
# 3     October
# 4        June
# 5      August
# 6    November
# 7      August
# 8    December
# 9     January
# Name: timestamp, dtype: object

# %%
df
# Out:
#             timestamp  transient_1  transient_2  transient_3  transient_4  \
# 0 2020-02-16 16:38:56           11          166          867           94
# 1 2020-11-21 11:59:50           62          166           83          756
# 2 2020-08-13 12:54:24            3            0          903          927
# 3 2020-10-12 06:14:03           62          225            8          191
# 4 2020-06-13 02:54:24           11          225           29          611
# 5 2020-08-13 12:54:24            3            0          105          117
# 6 2020-11-21 11:59:50           62          225          424           45
# 7 2020-08-13 12:54:24           62            0          455          268
# 8 2020-12-19 00:44:47           62          225          410          180
# 9 2019-01-01 04:30:07           11          300          437          273
#
#    transient_5  transient_6  transient_7  transient_8  transient_9  \
# 0           95          105          112          163            1
# ...

# %%
df['month'] = df['timestamp'].dt.month_name()

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   transient_1  10 non-null     int64
#  1   transient_2  10 non-null     int64
#  2   transient_3  10 non-null     int64
#  3   transient_4  10 non-null     int64
#  4   transient_5  10 non-null     int64
#  5   transient_6  10 non-null     int64
#  6   transient_7  10 non-null     int64
#  7   transient_8  10 non-null     int64
#  8   transient_9  10 non-null     int64
# dtypes: int64(9)
# memory usage: 848.0 bytes

# %%
df['timestamp'][:2].dt.month_name().str[:3]
# Out:
# 0    Feb
# 1    Nov
# Name: timestamp, dtype: object

# %%
#if (df['transient_1'].value>200 and df['transient_1'].value<800 , df['transient_1'].value/10):

# %% [raw]
# def minb(featur):
#         for j in (1,10):
#             if features.values(j)>200 and features.values(j)<800:
#                     features.values(j).replace(features.values(j)/10)
#
# minb(features)

# %% [raw]
# minb(features)

# %%
#df.loc[7]

# %%
df.loc[7,'transient_1']= 1
df.loc[7,'transient_2']= 2
df.loc[7,'transient_3']= 3
df.loc[7,'transient_4']= 4
df.loc[7,'transient_5']= 5
df.loc[7,'transient_6']= 6
df.loc[7,'transient_7']= 7
df.loc[7,'transient_8']= 8
df.loc[7,'transient_9']= 9

# %%
df.loc[7]
# Out:
# timestamp        2020-08-13 12:54:24
# transient_1                        1
# transient_2                        2
# transient_3                        3
# transient_4                        4
# transient_5                        5
# transient_6                        6
# transient_7                        7
# transient_8                        8
# transient_9                        9
# average                   236.666667
# average_7_max                    NaN
# month                         August
# Name: 7, dtype: object

# %%
rslt_df = df.sort_values(by = ['timestamp', 'transient_1'])
rslt_df
# Out:
#             timestamp  transient_1  transient_2  transient_3  transient_4  \
# 9 2019-01-01 04:30:07           11          300          437          273
# 0 2020-02-16 16:38:56           11          166          867           94
# 4 2020-06-13 02:54:24           11          225           29          611
# 7 2020-08-13 12:54:24            1            2            3            4
# 2 2020-08-13 12:54:24            3            0          903          927
# 5 2020-08-13 12:54:24            3            0          105          117
# 3 2020-10-12 06:14:03           62          225            8          191
# 1 2020-11-21 11:59:50           62          166           83          756
# 6 2020-11-21 11:59:50           62          225          424           45
# 8 2020-12-19 00:44:47           62          225          410          180
#
#    transient_5  transient_6  transient_7  transient_8  transient_9  \
# 9            4          273          661          217          943
# ...

# %%
for i in features:
    for j in range (2,10):
        transient_diff_i = features.values[j]-features.values[j-1]

transient_diff_i
# Out:
# array([ -51,   75,   27,   93, -939, -277, -297, -199,  459], dtype=int64)

# %%
df['transient_diff_i']= pd.DataFrame(transient_diff_i)

# %%
df
# Out:
#             timestamp  transient_1  transient_2  transient_3  transient_4  \
# 0 2020-02-16 16:38:56           11          166          867           94
# 1 2020-11-21 11:59:50           62          166           83          756
# 2 2020-08-13 12:54:24            3            0          903          927
# 3 2020-10-12 06:14:03           62          225            8          191
# 4 2020-06-13 02:54:24           11          225           29          611
# 5 2020-08-13 12:54:24            3            0          105          117
# 6 2020-11-21 11:59:50           62          225          424           45
# 7 2020-08-13 12:54:24            1            2            3            4
# 8 2020-12-19 00:44:47           62          225          410          180
# 9 2019-01-01 04:30:07           11          300          437          273
#
#    transient_5  transient_6  transient_7  transient_8  transient_9  \
# 0           95          105          112          163            1
# ...

# %%
features.values[0]
# Out:
# array([ 11, 166, 867,  94,  95, 105, 112, 163,   1], dtype=int64)

# %%
df.drop(['timestamp','month','average','average_7_max','transient_diff_i'],axis=1).multiply([1,10,100,20,40,17,43,26,21,77],axis = 0)
# Out:
#    transient_1  transient_2  transient_3  transient_4  transient_5  \
# 0           11          166          867           94           95
# 1          620         1660          830         7560         2720
# 2          300            0        90300        92700        75400
# 3         1240         4500          160         3820          100
# 4          440         9000         1160        24440        19080
# 5           51            0         1785         1989        12733
# 6         2666         9675        18232         1935           43
# 7           26           52           78          104          130
# 8         1302         4725         8610         3780        19803
# 9          847        23100        33649        21021          308
#
#    transient_6  transient_7  transient_8  transient_9
# 0          105          112          163            1
# 1         4240         2010         7350         3900
# 2        45500        35500        84800        49500
# ...
